# %% [markdown]
# # Microservice Architecture – Task 4
#
# ## Link to GitHub
#
# [https://github.com/Romko-studik/micro_basics/tree/micro_mg](https://github.com/Romko-studik/micro_basics/tree/micro_basics)
#
# ## Architecture
#
# The system includes three services:
#
# - **facade-service**: Handles POST/GET HTTP requests from the client
# - **logging-service**: Stores messages with deduplication and retry support
# - **messages-service**: Returns messages
#
# ## Running the Services
#
# Run in separate terminals:
#
# ```bash
# ./start_services.sh
# ```
#
# ### Tests:
# ```bash
# ./test.ch > result.log 2>&1
# ```
# First of all from result.log we can see that all of messages were sent succesfully and after sending /get 3 times we can see that in totall we get all of the messages sent:
# ![image-2.png](attachment:image-2.png)
#
# Now lets look at logs of individual services, here are logging services:
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# message services:
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
